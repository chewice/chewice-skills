# %% [markdown]
# # TODO：当前科学问题
# 说明上游输入和当前问题。本模板使用 Python kernel。

# %% [markdown]
# ## 工作目录
# 先确认 kernel 已从本 Notebook 所在目录启动；若不是，将下一 cell 的相对目标改为该目录。初始化只运行一次。

# %%
import os
from pathlib import Path

os.chdir(".")
print(Path.cwd())

import pandas as pd

# %% [markdown]
# ## 读取样本信息
# 查看实际字段、类型和少量记录，再确定后续分组；读取方式按真实格式调整。

# %%
data_path = Path("../data")
fn = data_path / "TODO_METADATA.tsv"
metadata = pd.read_csv(fn, sep="\t")

print(type(metadata))
metadata.head()

# %% [markdown]
# ## 根据观察继续
# 检查实际输出后续写下一步，选择依据留在调用附近。复用已有对象，上游改变时重跑相关下游 cells。

# %%
# TODO：检查后写入下一步。

# 后续确需这份表时，在相应片段保存，续做读取同一相对路径。
# out_path = Path("../results/TODO_STEP")
# out_path.mkdir(parents=True, exist_ok=True)
# fn = out_path / "metadata.tsv"
# metadata.to_csv(fn, sep="\t", index=False)

# %% [markdown]
# # TODO：当前科学问题
# 说明上游输入，以及本 Notebook 当前需要回答的问题。这个模板使用 Python kernel；R 分析应使用已有 R kernel 与 R 语法。

# %% [markdown]
# ## 读取并检查样本信息
# 展示实际字段和少量记录，再确定分组与对齐方式。本例使用 TSV，按实际输入调整读取调用。

# %%
from pathlib import Path

import pandas as pd

metadata_path = Path("inputs/TODO_METADATA.tsv")
metadata = pd.read_csv(metadata_path, sep="\t")
metadata.head()

# %% [markdown]
# ## 根据观察确定下一步
# 先检查上一 cell 的真实输出。证据充分时记录选择及依据并继续；关键科学取舍仍不明确时再询问用户。

# %%
# TODO：检查后写入下一步；当前没有可执行的下游调用。
# 不预填未知分组、阈值或模型，不把 None 传入模型。

# %% [markdown]
# 在同一 kernel 中继续使用已有对象。关键变换后展示相关内容或诊断；上游选择改变时重跑受影响的 cells。只保存有明确科研或下游用途的产物。

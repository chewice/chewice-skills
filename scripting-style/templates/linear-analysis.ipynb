# %% [markdown]
# # TODO: current scientific question
# State the upstream object and what this notebook needs to decide.

# %%
from pathlib import Path

import TODO_PACKAGE

# %%
input_path = Path("inputs/TODO_INPUT")
output_path = Path("derived/TODO_OUTPUT")

# Replace with the project's real reader.
analysis_data = None
analysis_data

# %% [markdown]
# ## Optional representative trial
# Keep this cell only when the operation will later be batched and still needs a concrete trial.

# %%
representative_id = "TODO_REPRESENTATIVE_ID"
# representative_result = TODO_METHOD(analysis_data, representative_id)
# representative_result

# %% [markdown]
# ## Optional candidate comparison
# Keep these cells only when the task compares candidates. Do not select a value until diagnostics have been inspected.

# %%
candidate_values = []  # TODO: values justified for this analysis
candidate_results = {}

for candidate_value in candidate_values:
    # candidate_results[candidate_value] = TODO_METHOD(
    #     analysis_data, candidate_value=candidate_value
    # )
    pass

candidate_results

# %%
selected_value = None  # TODO: set after inspecting the comparison above.
# analysis_result = TODO_DOWNSTREAM(analysis_data, selected_value)

# %% [markdown]
# ## Optional interpretation
# When useful after execution, record an observed limitation or next question. Save only artifacts needed for review or downstream work.
